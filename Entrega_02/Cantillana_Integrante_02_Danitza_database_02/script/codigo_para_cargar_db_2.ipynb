# %%
import pandas as pd

df = pd.read_csv('/content/BASE_DE_DATOS_CALIDAD_ZONAS_VERDES.csv', sep=';')
df.head()
# Out:
#    OBJECTID  TARGET_FID    CUT                     REGION PROVINCIA    COMUNA  \
# 0      3393       31552  13101  METROPOLITANA DE SANTIAGO  SANTIAGO  SANTIAGO
# 1     17383       90140  13101  METROPOLITANA DE SANTIAGO  SANTIAGO  SANTIAGO
# 2     17384       90141  13101  METROPOLITANA DE SANTIAGO  SANTIAGO  SANTIAGO
# 3      2026       27739  13101  METROPOLITANA DE SANTIAGO  SANTIAGO  SANTIAGO
# 4     18402       27740  13101  METROPOLITANA DE SANTIAGO  SANTIAGO  SANTIAGO
#
#    COD_URBANO_CENSO URBANO_CENSO TIPO_EP     NOMBRE_EP  ...     DE CALIDAD  \
# 0            131011     SANTIAGO  PARQUE  DE LOS REYES  ...  83,33   91,75
# 1            131011     SANTIAGO  PARQUE  DE LOS REYES  ...  48,33   80,50
# 2            131011     SANTIAGO  PARQUE  DE LOS REYES  ...  33,33   60,81
# 3            131011     SANTIAGO   PLAZA                ...  61,67   41,58
# 4            131011     SANTIAGO   PLAZA                ...  -1,00   -1,00
#
# ...
